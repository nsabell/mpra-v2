# %% [markdown]
# ## GWAS and eQTL Colocalizations Across MPRA Variants

# %%
library(tidyverse)
library(data.table)
library(fs)
library(bedr)
library(ggpubr)
library(ggrepel)
library(patchwork)
library(ggridges)
library(parallel)
library(pbapply)

setwd("~/work/mpra-v2")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
#
#
# ######################
# #### bedr v1.0.7 ####
# ######################
#
# checking binary availability...
#   * Checking path for bedtools... FAIL
#   * Checking path for bedops... FAIL
#   * Checking path for tabix... PASS
#     /scg/apps/software/jupyter/python_3.7/bin/tabix
# tests and examples will be skipped on R CMD check if binaries are missing

# %%
mpraStats = fread("sumstats/1KG_novaSeq_DESeq2_Love_Base2.txt", header = T, stringsAsFactors = F)

mpraStats.tmp = mpraStats[,c(3,4,5,6,7,8,9,23,27,29,30,33)]
mpraStats.tmp = subset(mpraStats.tmp, haploFlag == "Base" & !is.na(geneID))
mpraStats.tmp = separate_rows(mpraStats.tmp, geneID,sep = ",")

# %%
haploVarsExpr = fread("sumstats/haplotype/Expression.txt")
haploVars = fread("sumstats/haplotype/Allele3.txt")

haploVars$log2FoldChange_expr = haploVarsExpr$log2FoldChange
haploVars$padj_expr = haploVarsExpr$padj

haploVarsFormat = haploVars %>% 
                    filter(Pool == "1KGTest") %>%
                    select(chrom,pos.x,pos.y,geneID,strand,ref.x,alt.x,haploFlag.x,
                           log2FoldChange_expr,padj_expr,log2FoldChange,lfcSE,padj)

pos1 = haploVarsFormat[,-2]
pos2 = haploVarsFormat[,-3]

names(pos1) = c("chrom","pos","geneID","strand","ref","alt","haploFlag","log2FoldChange_expr","padj_expr","log2FoldChange_allele","lfcSE_allele","padj_allele")
names(pos2) = c("chrom","pos","geneID","strand","ref","alt","haploFlag","log2FoldChange_expr","padj_expr","log2FoldChange_allele","lfcSE_allele","padj_allele")

haploVarsFormat = rbind(pos1,pos2)
mpraStats.tmp = rbind(mpraStats.tmp,haploVarsFormat)

# %%
hgTable = fread("annotation/hgConversionTable.txt", stringsAsFactors = F, header = T)
mpraStats.tmp = merge(mpraStats.tmp, unique(hgTable),
                      by.x = c("chrom","pos"),
                      by.y = c("hg19_chrom","hg19_pos"))
eqtl.sub = fread("zcat annotation/Cells_EBV-transformed_lymphocytes.allpairs.subset.bed.gz")

# %%
files = dir_ls("/oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/",glob="*txt.gz",recurse = T)
names(files) = str_split_fixed(names(files),pattern = "/",n=11)[,11]
files = paste0("zcat ",files)
data = suppressWarnings(files %>% map_dfr(fread, .id = "source"))
data$gene_id = gsub("\\..*","",data$gene_id, perl=T)
# Out:
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ADIPOGen_Adiponectin__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Eosinophil_counts__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Granulocyte_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_High_light_scatter_reticulocyte_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Lymphocyte_counts__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Monocyte_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Myeloid_white_cell_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Neutrophil_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Platelet_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Red_blood_cell_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Reticulocyte_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Sum_basophil_neutrophil_counts__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Sum_eosinophil_basophil_counts__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_Sum_neutrophil_eosinophil_counts__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Astle_et_al_2016_White_blood_cell_count__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/BCAC_ER_negative_BreastCancer_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/BCAC_ER_positive_BreastCancer_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/BCAC_Overall_BreastCancer_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/CARDIoGRAM_C4D_CAD_ADDITIVE__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/CKDGen_Chronic_Kidney_Disease__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/CNCR_Insomnia_all__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/DIAGRAM_T2D_TRANS_ETHNIC__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EAGLE_Eczema__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EGG_BL__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EGG_BMI_HapMapImputed__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EGG_BW3_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EGG_Pubertal_growth_10F__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/EGG_Pubertal_growth_12M__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ENIGMA_Intracraneal_Volume__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GABRIEL_Asthma__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GEFOS_Forearm__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_2015_BMI_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_2017_BMI_Active_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_HEIGHT__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_HIP_Combined_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_WC_Combined_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GIANT_WHR_Combined_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GLGC_Mc_HDL__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GLGC_Mc_LDL__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GLGC_Mc_TG__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/GPC-NEO-NEUROTICISM__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/HRGene_HeartRate__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IBD.EUR.Crohns_Disease__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IBD.EUR.Inflammatory_Bowel_Disease__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IBD.EUR.Ulcerative_Colitis__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ICBP_DiastolicPressure__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ICBP_SystolicPressure__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IGAP_Alzheimer__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ILAE_Genetic_generalised_epilepsy__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IMMUNOBASE_Celiac_disease_hg19__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IMMUNOBASE_Multiple_sclerosis_hg19__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/IMMUNOBASE_Systemic_lupus_erythematosus_hg19__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/ISGC_Malik_2016_METASTROKE_all_strokes__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Jones_et_al_2016_Chronotype__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/Jones_et_al_2016_SleepDuration__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGIC_FastingGlucose__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGIC_ln_FastingInsulin__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGNETIC_CH2.DB.ratio__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGNETIC_HDL.C__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGNETIC_IDL.TG__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/MAGNETIC_LDL.C__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/PGC_ADHD_EUR_2017__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/PGC_ASD_2017_CEU__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/RA_OKADA_TRANS_ETHNIC__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/SSGAC_Depressive_Symptoms__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/SSGAC_Education_Years_Pooled__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/TAGC_Asthma_EUR__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_1160_Sleep_duration__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_1180_Morning_or_evening_person_chronotype__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_1200_Sleeplessness_or_insomnia__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_1807_Fathers_age_at_death__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1065_self_reported_hypertension__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1094_self_reported_deep_venous_thrombosis_dvt__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1111_self_reported_asthma__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1154_self_reported_irritable_bowel_syndrome__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1222_self_reported_type_1_diabetes__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1223_self_reported_type_2_diabetes__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# ...
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1462_self_reported_crohns_disease__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1463_self_reported_ulcerative_colitis__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1464_self_reported_rheumatoid_arthritis__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1466_self_reported_gout__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1473_self_reported_high_cholesterol__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20002_1616_self_reported_insomnia__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20016_Fluid_intelligence_score__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20022_Birth_weight__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_20127_Neuroticism_score__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_21001_Body_mass_index_BMI__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_23099_Body_fat_percentage__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_2395_2_Hair_or_balding_pattern_Pattern_2__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_2395_3_Hair_or_balding_pattern_Pattern_3__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_2395_4_Hair_or_balding_pattern_Pattern_4__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_3526_Mothers_age_at_death__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_50_Standing_height__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_6150_1_Vascular_or_heart_problems_diagnosed_by_doctor_Heart_attack__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_6152_5_diagnosed_by_doctor_Blood_clot_in_the_leg_DVT__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_6152_7_diagnosed_by_doctor_Blood_clot_in_the_lung__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_6152_8_diagnosed_by_doctor_Asthma__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_6152_9_diagnosed_by_doctor_Hayfever_allergic_rhinitis_or_eczema__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_G40_Diagnoses_main_ICD10_G40_Epilepsy__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/UKB_G43_Diagnoses_main_ICD10_G43_Migraine__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/pgc.scz2__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.
#
# Taking input= as a system command ('zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/tag.evrsmk.tbl__PM__Cells_EBV-transformed_lymphocytes.txt.gz') and a variable has been used in the expression passed to `input=`. Please use fread(cmd=...). There is a security concern if you are creating an app, and the app could have a malicious user, and the app is not running in a secure environment; e.g. the app is running as root. Please read item 5 in the NEWS file for v1.11.6 for more information and for the option to suppress this message.

# %%
hitCounts = mpraStats.tmp %>% 
                filter(!is.na(geneID) & geneID != "") %>% 
                mutate(hit = ifelse(padj_allele < 5e-2 & padj_expr < 5e-2,"hit","nonhit")) %>%
                group_by(geneID, hit) %>% 
                summarize(count=n())

hitCounts = merge(hitCounts, data,
                  by.x="geneID",by.y = "gene_id")

posteriors = hitCounts %>% 
                group_by(geneID,source,p0,p1,p2,p3,p4) %>% 
                spread(hit,count,fill=0)

posteriors$file = apply(posteriors,1,function(x) files[as.integer(x[2])])
posteriors$file = gsub("zcat /oak/stanford/groups/smontgom/shared/GTEx/barbeira_coloc/results_enloc_priors/Cells_EBV-transformed_lymphocytes/","",posteriors$file)
posteriors$file = gsub("__PM__Cells_EBV-transformed_lymphocytes.txt.gz","",posteriors$file)

hitsOnly = subset(posteriors, (hit+nonhit>=10) & (hit > 0) & (p3 + p4 > 0.5))
# Out:
# `summarise()` regrouping output by 'geneID' (override with `.groups` argument)

# %%
write.table(hitsOnly, "sumstats/gtex-gwas-coloc-searchList.txt", quote = F, sep = "\t", col.names = T, row.names = F)

# %%
annotateSumStats = function(colocVector, mpraStats.tmp = mpraStats.tmp, eqtl.sub = eqtl.sub){

    library(bedr)
    
    gene = colocVector[1]
    trait = colocVector[10]
    
    gwas = paste0("~/work/mpra-v2/gwas/imputed_",trait,".subset.txt.gz")

    testVars = subset(mpraStats.tmp, geneID == gene)
    sigVars = subset(mpraStats.tmp, geneID == gene & padj_allele < 5e-2 & padj_expr < 5e-2)
    
    e1 = subset(eqtl.sub, V6 == gene)

    minPos = as.character(min(e1$V2))
    maxPos = as.character(max(e1$V3))
    chrom = unique(e1$V1)
    query = paste0(chrom,":",minPos,"-",maxPos)

    g1 = tryCatch( tabix(region = query,file.name = gwas,check.chr = T) ,
                  error = function(e) {return(data.frame("V2" = 1, "V9" = 1))} )
    g1$V9 = as.numeric(g1$V9)
    
    testedEQTL = subset(e1, V2 %in% testVars$hg38_pos)
    testedGWAS = subset(g1, V2 %in% testVars$hg38_pos)
    
    sigEQTL = subset(e1, V2 %in% sigVars$hg38_pos)
    sigGWAS = subset(g1, V2 %in% sigVars$hg38_pos)

    maxSigEQTL = ifelse(nrow(sigEQTL) > 0,max(-log10(sigEQTL$V8), na.rm = T),0)
    maxSigGWAS = ifelse(nrow(sigGWAS) > 0,max(-log10(sigGWAS$V9), na.rm = T),0)
    
    maxNonSigEQTL = ifelse(nrow(testedEQTL) > 0, max(-log10(testedEQTL$V8), na.rm = T),0)
    maxNonSigGWAS = ifelse(nrow(testedGWAS) > 0, max(-log10(testedGWAS$V9), na.rm = T),0)
    
    return(c(maxSigEQTL,maxSigGWAS,maxNonSigEQTL,maxNonSigGWAS))
}

# %%
# without a cluster

results = data.frame("maxSigEQTL" = NULL,"maxSigGWAS" = NULL,"maxNonSigEQTL" = NULL,"maxNonSigGWAS" = NULL)

for(i in 1:nrow(hitsOnly)){
        
    p = annotateSumStats(c(hitsOnly[i,]), mpraStats.tmp = mpraStats.tmp, eqtl.sub = eqtl.sub)
    
    results = rbind(results,p)
}

# %%
# with a cluster

cl = makeCluster(15)
maxSumStats = parApply(cl,hitsOnly,1,annotateSumStats,mpraStats.tmp = mpraStats.tmp, eqtl.sub = eqtl.sub)
stopCluster(cl)

maxSumStats = as.data.frame(t(maxSumStats))
names(maxSumStats) = c("maxSigEQTL","maxSigGWAS","maxNonSigEQTL","maxNonSigGWAS")

hitsOnlyWithSumStats = cbind(as.data.frame(hitsOnly), maxSumStats)
write.table(hitsOnlyWithSumStats, "sumstats/gtex-gwas-colocs.txt", col.names = T ,row.names = F, sep = "\t", quote = F)

# %%
hitsOnlyWithSumStats = fread("sumstats/gtex-gwas-colocs.txt")
ensg2gene = read.delim("annotation/ensg2gene.txt", header = F, stringsAsFactors = F) %>% 
                separate(V1,c("ensg","gene"),sep = "_",extra = "merge")

hitsOnlyWithSumStats = merge(hitsOnlyWithSumStats, ensg2gene, by.x = "geneID",by.y="ensg")
hitsOnlyWithSumStats[which(hitsOnlyWithSumStats$geneID == "ENSG00000164308"),"gene"] = "ERAP2" 
hitsOnlyWithSumStats[which(hitsOnlyWithSumStats$gene == "C8orf40"),"gene"] = "SMIM19"
hitsOnlyWithSumStats[which(hitsOnlyWithSumStats$gene == "C8orf70"),"gene"] = "ZC2HC1A"
hitsOnlyWithSumStats[which(hitsOnlyWithSumStats$gene == "C12orf48"),"gene"] = "PARBP"

# %%
hitsFilt = hitsOnlyWithSumStats %>% 
                filter(maxSigEQTL > -log10(5e-5) & maxSigGWAS > -log10(5e-8)) %>% 
                group_by(file,gene,hit) %>% 
                summarize(count=n())
dim(hitsOnlyWithSumStats)
unique(hitsFilt$file)
# Out:
# `summarise()` regrouping output by 'file', 'gene' (override with `.groups` argument)
# [1] 4443   15
#  [1] "Astle_et_al_2016_Eosinophil_counts"
#  [2] "Astle_et_al_2016_Granulocyte_count"
#  [3] "Astle_et_al_2016_High_light_scatter_reticulocyte_count"
#  [4] "Astle_et_al_2016_Lymphocyte_counts"
#  [5] "Astle_et_al_2016_Monocyte_count"
#  [6] "Astle_et_al_2016_Myeloid_white_cell_count"
#  [7] "Astle_et_al_2016_Neutrophil_count"
#  [8] "Astle_et_al_2016_Platelet_count"
#  [9] "Astle_et_al_2016_Red_blood_cell_count"
# [10] "Astle_et_al_2016_Reticulocyte_count"
# [11] "Astle_et_al_2016_Sum_basophil_neutrophil_counts"
# [12] "Astle_et_al_2016_Sum_eosinophil_basophil_counts"
# [13] "Astle_et_al_2016_Sum_neutrophil_eosinophil_counts"
# [14] "Astle_et_al_2016_White_blood_cell_count"
# [15] "CKDGen_Chronic_Kidney_Disease"
# [16] "EGG_BW3_EUR"
# [17] "EGG_Pubertal_growth_12M"
# [18] "GABRIEL_Asthma"
# [19] "GIANT_HEIGHT"
# [20] "GIANT_HIP_Combined_EUR"
# [21] "GLGC_Mc_HDL"
# [22] "IBD.EUR.Crohns_Disease"
# [23] "IBD.EUR.Inflammatory_Bowel_Disease"
# [24] "IBD.EUR.Ulcerative_Colitis"
# [25] "IMMUNOBASE_Multiple_sclerosis_hg19"
# [26] "IMMUNOBASE_Systemic_lupus_erythematosus_hg19"
# [27] "RA_OKADA_TRANS_ETHNIC"
# [28] "TAGC_Asthma_EUR"
# [29] "UKB_20002_1111_self_reported_asthma"
# [30] "UKB_20002_1225_self_reported_hyperthyroidism_or_thyrotoxicosis"
# [31] "UKB_20002_1226_self_reported_hypothyroidism_or_myxoedema"
# [32] "UKB_20016_Fluid_intelligence_score"
# [33] "UKB_20022_Birth_weight"
# [34] "UKB_20127_Neuroticism_score"
# [35] "UKB_21001_Body_mass_index_BMI"
# [36] "UKB_23099_Body_fat_percentage"
# [37] "UKB_50_Standing_height"
# [38] "UKB_6152_8_diagnosed_by_doctor_Asthma"
# [39] "UKB_6152_9_diagnosed_by_doctor_Hayfever_allergic_rhinitis_or_eczema"

# %%
gwasLabels = data.frame("file" = unique(hitsFilt$file),
                       "trait" = c("Eosinophil Count",
                                   "Granuloctye Count",
                                   "HLS Reticulocyte Count",
                                   "Lymphocyte Count",
                                   "Monocyte Count",
                                   "Myeloid White Cell Count",
                                   "Neutrophil Count",
                                   "Platelet Count",
                                   "Red Blood Cell Count",
                                   "Reticulocyte Count",
                                   "Basophil+Neutrophil Count",
                                   "Basophil+Eosinophil Count",
                                   "Neutrophil+Eosinophil Count",
                                   "White Blood Cell Count",
                                   "Chronic Kidney Disease",
                                   "Birth Weight",
                                   "Pubertal Growth",
                                   "Asthma (GABRIEL)",
                                   "Height (GIANT)",
                                   "Waist (GIANT)",
                                   "HDL",
                                   "Crohns Disease",
                                   "Inflammatory Bowel Disease",
                                   "Ulcerative Colitis",
                                   "Multiple Sclerosis",
                                   "Systemic Lupus Erythematosus",
                                   "Rheumatoid Arthritis",
                                   "Asthma (TAGC)",
                                   "Asthma, Self-Reported (UKB)",
                                   "Hyperthyroidism/Thyrotoxicosis, Self-Reported (UKB)",
                                   "Hypothyroidism/Myxoedema, Self-Reported (UKB)",
                                   "Fluid Intelligence Score (UKB)",
                                   "Birth Weight (UKB)",
                                   "Neuroticism (UKB)",
                                   "Body Mass Index (UKB)",
                                   "Body Fat Percentage (UKB)",
                                   "Height (UKB)",
                                   "Asthma, Diagnosed (UKB)",
                                   "Allergic Rhinitis/Eczema, Diagnosed (UKB)"))

hitsFilt = merge(hitsFilt, gwasLabels, by="file")

# %%
write.table(hitsFilt,"sumstats/gtex-gwas-colocs-summary.txt", col.names = T, row.names= F, quote = F, sep = "\t")

# %%
hitsFilt = fread("sumstats/gtex-gwas-colocs-summary.txt")

hitsFilt$hit[which(hitsFilt$hit > 9)] = 9

# %%
options(repr.plot.width=21,repr.plot.height=12)

gwasHeatmap = ggplot(hitsFilt) + 
    geom_tile(aes(y = factor(trait, levels = rev(levels(factor(trait)))),
                  x = reorder(gene,hit), 
                  fill = as.factor(hit)),color = "black",size=2) +
    theme_pubr(base_size = 20,x.text.angle = 45) +
    scale_fill_brewer(name="Number of MPRA Hits in Region", palette = "Set1", labels = c("1","2","3","4","5","6","7","8",">= 9")) + 
    theme(axis.title = element_blank(),
          legend.title=element_text(size=25),
          legend.text=element_text(size=25),
          legend.key.size = unit(1.4, "cm"),
          plot.margin = margin(t = 1, r = 1, b = 1, l = 50, unit = "pt")) + 
    scale_y_discrete(position = "right") +
    guides(fill=guide_legend(nrow=1,byrow=TRUE)) 

gwasHeatmap
# Out:
# plot without title

# %%
colocsToPlot = hitsOnlyWithSumStats %>% 
                    filter(maxSigEQTL > -log10(5e-5) & maxSigGWAS > -log10(5e-8)) %>% 
                    group_by(file,geneID,gene,hit) %>% 
                    summarize(count=n())
# Out:
# `summarise()` regrouping output by 'file', 'geneID', 'gene' (override with `.groups` argument)

# %%
plotColoc = function(gene,gwas,geneName,gwasName){
    
    gwas = paste0("gwas/imputed_",gwas,".subset.txt.gz")
    testVars = subset(mpraStats.tmp, geneID == gene)
    sigVars = subset(mpraStats.tmp, geneID == gene & padj_allele < 5e-2 & padj_expr < 5e-2)

    e1 = subset(eqtl.sub, V6 == gene)

    minPos = as.character(min(e1$V2))
    maxPos = as.character(max(e1$V3))
    chrom = unique(e1$V1)
    query = paste0(chrom,":",minPos,"-",maxPos)

    g1 = tabix(region = query,file.name = gwas,check.chr = T)

    eqtlPlot = ggplot(e1) + 
                    geom_point(aes(x = as.numeric(V2), y = -log10(V8)),color = "black") + 
                    geom_point(data = subset(e1, V2 %in% testVars$hg38_pos), 
                               aes(x = as.numeric(V2), y = -log10(V8)), color = "dodgerblue", size = 3) + 
                    geom_point(data = subset(e1, V2 %in% sigVars$hg38_pos),
                               aes(x = as.numeric(V2), y = -log10(V8)),
                               color = "red", fill = "red", size = 5, shape = 23) + 
                    theme_pubr(base_size = 14) + #geom_vline(xintercept = 135418217) + geom_vline(xintercept = 135512325) +
                    ylab(paste0(geneName," -logP")) + xlab("hg38 position") #+ xlim(c(42300000,42700000))

    gwasPlot = ggplot(g1) + 
                    geom_point(aes(x = as.numeric(V2), y = -log10(as.numeric(V9))),color = "black") + 
                    geom_point(data = subset(g1, V2 %in% testVars$hg38_pos), 
                               aes(x = as.numeric(V2), y = -log10(as.numeric(V9))), color = "dodgerblue", size = 3) + 
                    geom_point(data = subset(g1, V2 %in% sigVars$hg38_pos),
                               aes(x = as.numeric(V2), y = -log10(as.numeric(V9))),
                               color = "red", fill = "red", size = 5, shape = 23) + 
                    theme_pubr(base_size = 14)  + #geom_vline(xintercept = 135418217) + geom_vline(xintercept = 135512325) +
                    ylab(paste0(gwasName," -logP")) + xlab("hg38 position") #+ geom_hline(yintercept = -log10(5e-8))

    m = merge(g1,e1,by=c("V1","V2"))

    comparePlot = ggplot(data = m, 
                         aes(x = -log10(as.numeric(V9.x)),y = -log10(as.numeric(V8.y)))) + 
                        geom_point() +
                        geom_point(data = subset(m, V2 %in% testVars$hg38_pos),
                                   aes(x = -log10(as.numeric(V9.x)), 
                                       y = -log10(as.numeric(V8.y))), 
                                   color = "dodgerblue", size = 3) +
                        geom_point(data = subset(m, V2 %in% sigVars$hg38_pos),
                                   aes(x = -log10(as.numeric(V9.x)), 
                                       y = -log10(as.numeric(V8.y))), 
                                   color = "red", fill = "red", size = 5, shape = 23) + 
                        theme_pubr(base_size = 14) +
                        xlab("GWAS -logP") + ylab("eQTL -logP")
    
    finalPlot = eqtlPlot|gwasPlot|comparePlot
    return(finalPlot)
}

pdf("MPRA-GTEx-coloc-all.pdf",width = 15, height = 5, useDingbats = F)
for(i in 1:nrow(colocsToPlot)){
    
    theRow = colocsToPlot[i,]
    print(theRow[2])
    thePlot = plotColoc(as.character(theRow[2]),theRow[1],theRow[3],theRow[1])
    print(thePlot)
}
dev.off()
# Out:
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000178252
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Eosinophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b747fb4f5.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Eosinophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b424e48b1.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Granulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b359a1753.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Granulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b66239e3a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Granulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b35ccae80.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_High_light_scatter_reticulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b16d1c73a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000197256
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_High_light_scatter_reticulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4333c8f7.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000104427
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Lymphocyte_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5f7aa313.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Lymphocyte_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b772f1cb2.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000174130
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Lymphocyte_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b3434cd7a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Lymphocyte_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b27778fdb.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Lymphocyte_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b1eb38255.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000103671
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Monocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b40bc35e9.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000116171
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Monocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b546a57f5.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Monocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b78b1d86b.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Myeloid_white_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86bf638164.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Myeloid_white_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b1a043b81.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Myeloid_white_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b62fba430.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6e5c3370.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000135541
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5086cf6d.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000137806
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b782b5ac.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000164414
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b2c110536.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b37e8924.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Neutrophil_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5fe0d0cf.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000007341
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b15bb3210.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000059691
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86becd4fe8.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000091640
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6456e09c.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000100266
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b46226711.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000130956
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4deeec7.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000146535
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Platelet_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b541c42c0.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176209
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Red_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b3af1b4c3.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Red_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b45ecc9f7.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Reticulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b3c6d936a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Reticulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86bb3f98f.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000197256
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Reticulocyte_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7d824ac9.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_basophil_neutrophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b58968f1a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000137806
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_basophil_neutrophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4760145b.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_basophil_neutrophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b36236e3e.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_basophil_neutrophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b49d3de18.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000178252
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_eosinophil_basophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b293776e4.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_eosinophil_basophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b745ed4a9.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_neutrophil_eosinophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b1f2dd1e8.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_neutrophil_eosinophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b1b0b1a08.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_Sum_neutrophil_eosinophil_counts.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5db4ad1e.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000011295
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_White_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b3db9f876.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000059691
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_White_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6913fb48.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_White_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7c3b7029.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_White_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b56ba4039.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000186470
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_Astle_et_al_2016_White_blood_cell_count.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b79148083.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000171763
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_CKDGen_Chronic_Kidney_Disease.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b32819694.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_EGG_BW3_EUR.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7702075e.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000146535
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_EGG_Pubertal_growth_12M.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b38a02a83.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GABRIEL_Asthma.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5c0e376d.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000055483
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b37026b11.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000129055
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b77f2d559.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000130956
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86baf1e5bd.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000146535
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7634bfd3.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000169193
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6fbf79a3.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000182923
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b24be85a7.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000213533
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4cd8a0b0.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000214078
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HEIGHT.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b67f418af.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000146535
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GIANT_HIP_Combined_EUR.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b3c32ec0d.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_GLGC_Mc_HDL.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b10686087.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000164308
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
# ...
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b50aa9e65.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000128408
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b176ced39.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000129055
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7bdedb2.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000130956
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b56b63658.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000137806
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b54894b57.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000140400
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6f154a7a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000146535
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b19ee9b3b.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000157653
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b2d5b4b85.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000166435
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b70cfd6fb.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000169193
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4103b267.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176732
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b624bc0ba.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000176974
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b71a46e38.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000178252
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5c8eea88.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000182923
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b54176c0.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000185480
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b55d7a269.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000214078
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_50_Standing_height.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4b0d2f34.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000135541
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_8_diagnosed_by_doctor_Asthma.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b4213596b.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_8_diagnosed_by_doctor_Asthma.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5c2d36c9.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000174130
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_8_diagnosed_by_doctor_Asthma.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b7e9df1e6.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000135541
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_9_diagnosed_by_doctor_Hayfever_allergic_rhinitis_or_eczema.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b5a87e93a.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000172057
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_9_diagnosed_by_doctor_Hayfever_allergic_rhinitis_or_eczema.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b6f2576c9.bed '
# # A tibble: 1 x 1
# # Groups:   geneID [1]
#   geneID
#   <chr>
# 1 ENSG00000174130
# TABIX-QUERY
#  * Processing input (1):
# CONVERT TO BED
#  * Checking input type... PASS
#    Input is in index format
# VALIDATE REGIONS
#  * Check if index is a string... PASS
#  * Check index pattern... PASS
#  * Check for missing values... PASS
#  * Check for larger start position... PASS.
#  * Check if zero based... PASS
#  * Checking sort order... PASS
#  * Checking for overlapping 'contiguous' regions... FAIL
#    The input for object has overlapping features!
#    This can cause unexpected results for some set operations.
#    i.e. x <- bedr.merge.region(x)
#
# bash -c 'tabix  gwas/imputed_UKB_6152_9_diagnosed_by_doctor_Hayfever_allergic_rhinitis_or_eczema.subset.txt.gz -R /tmp/RtmpPLd0j0/_c86b2a99a6b0.bed '
# png
#   2

# %%
sessionInfo()
# Out:
# R version 3.6.0 (2019-04-26)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /usr/lib64/libopenblas-r0.3.3.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] pbapply_1.4-3     ggridges_0.5.2    patchwork_1.1.0   ggrepel_0.8.2
#  [5] ggpubr_0.4.0      bedr_1.0.7        fs_1.5.0          data.table_1.13.2
#  [9] forcats_0.5.0     stringr_1.4.0     dplyr_1.0.2       purrr_0.3.4
# [13] readr_1.4.0       tidyr_1.1.2       tibble_3.0.4      ggplot2_3.3.2
# [17] tidyverse_1.3.0
#
# loaded via a namespace (and not attached):
#  [1] lubridate_1.7.9      RColorBrewer_1.1-2   httr_1.4.2
#  [4] repr_1.1.0           tools_3.6.0          backports_1.2.0
#  [7] utf8_1.1.4           R6_2.5.0             DBI_1.1.0
# [10] colorspace_2.0-0     withr_2.3.0          tidyselect_1.1.0
# [13] curl_4.3             compiler_3.6.0       VennDiagram_1.6.20
# [16] cli_2.1.0            rvest_0.3.6          formatR_1.7
# [19] Cairo_1.5-12.2       xml2_1.3.2           labeling_0.4.2
# [22] scales_1.1.1         pbdZMQ_0.3-3.1       digest_0.6.27
# [25] foreign_0.8-76       R.utils_2.10.1       rio_0.5.16
# [28] base64enc_0.1-3      pkgconfig_2.0.3      htmltools_0.5.0
# [31] dbplyr_2.0.0         rlang_0.4.8          readxl_1.3.1
# [34] rstudioapi_0.12      farver_2.0.3         generics_0.1.0
# [37] jsonlite_1.7.1       zip_2.1.1            car_3.0-10
# [40] R.oo_1.24.0          magrittr_1.5         futile.logger_1.4.3
# [43] Rcpp_1.0.5           IRkernel_1.1.1       munsell_0.5.0
# [46] fansi_0.4.1          abind_1.4-5          lifecycle_0.2.0
# [49] R.methodsS3_1.8.1    stringi_1.5.3        yaml_2.2.1
# [52] carData_3.0-4        plyr_1.8.6           grid_3.6.0
# [55] crayon_1.3.4         IRdisplay_0.7.0      haven_2.3.1
# [58] hms_0.5.3            ps_1.4.0             pillar_1.4.6
# [61] uuid_0.1-4           ggsignif_0.6.0       futile.options_1.0.1
# [64] reprex_0.3.0         glue_1.4.2           evaluate_0.14
# [67] getPass_0.2-2        lambda.r_1.2.4       modelr_0.1.8
# [70] vctrs_0.3.4          testthat_3.0.0       cellranger_1.1.0
# [73] gtable_0.3.0         assertthat_0.2.1     openxlsx_4.2.3
# [76] broom_0.7.2          rstatix_0.6.0        ellipsis_0.3.1
